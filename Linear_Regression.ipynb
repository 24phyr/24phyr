# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv("Salary_Data.csv")
x = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5283/101038106.py in <cell line: 0>()
# ----> 1 dataset = pd.read_csv("Salary_Data.csv")
#       2 x = dataset.iloc[:, :-1].values
#       3 Y = dataset.iloc[:, -1].values
#
# ...

# %%
print(x)

# %% [markdown]
# # Splitting the dataset into training set and testing set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x,Y,test_size =1/3,random_state = 0)
print(x_train)

# %% [markdown]
# # Training the Simple Linear Regression model on the training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,Y_train)

# %% [markdown]
# y = mx + c

# %%
print(regressor.coef_) # value of m (1 yoe hoile 9345 barte hobe)

# %%
print(regressor.intercept_) # value of c (with no yoe starting salary should )

# %%
print(regressor.predict([[87]]))

# %% [markdown]
# # Visualizing the training set result

# %%
plt.scatter(x_train, Y_train, color= 'red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show

# %%
font1 = {'family' : 'serif', 'color' : 'blue', 'size' : 20}

# %% [markdown]
# # Visualizing the Test Set

# %%
plt.scatter(x_test, Y_test, color='red')
plt.plot(x_train, regressor.predict(x_train), color='blue')
plt.title('Salary vs Experience (Test set)' , fontdict=font1)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Statistical Significance of the Model

# %%
import statsmodels.api as sm
x_train_sm = sm.add_constant(x_train)
lr = sm.OLS(Y_train, x_train_sm).fit()
lr.summary()
